# %%
import PyPDF2
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from gensim.models import Word2Vec
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import string
from PyQt5.QtWidgets import QApplication, QFileDialog

# %%
# Download NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to read text from a PDF file
def read_pdf(file_path):
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
# Preprocess the text
def preprocess(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return tokens

# %%
# Function to generate a document vector using Word2Vec
def get_document_vector(tokens, model):
    vectors = [model.wv[word] for word in tokens if word in model.wv]
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# %%
def select_files():
    app = QApplication([])
    files, _ = QFileDialog.getOpenFileNames(None, "Select PDF files", "", "PDF files (*.pdf)")
    return files

# %%
# Test the function
# Select the files
file_paths = select_files()
print(file_paths)
# Out:
# ['D:/BU/aa research/journal articles/AML/Acute Myeloid Leukemia A Review.pdf', 'D:/BU/aa research/journal articles/AML/Diagnosis and management of acute myeloid leukemia in adults.pdf']

# %%
# Read and preprocess the text from the selected PDF files
text1 = preprocess(read_pdf(file_paths[0]))
text2 = preprocess(read_pdf(file_paths[1]))

# %%
# Combine the tokenized sentences for training Word2Vec
sentences = [text1, text2]

# %%
# Train a Word2Vec model on the sentences
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, sg=1)

# %%
# Generate document vectors
doc_vector_1 = get_document_vector(text1, model)
doc_vector_2 = get_document_vector(text2, model)

# %%
# Calculate cosine similarity between the two document vectors
similarity = cosine_similarity([doc_vector_1], [doc_vector_2])

# %%
# Print the tokenized sentences and their document vectors
print("Tokenized Document 1:", text1)
print("Tokenized Document 2:", text2)
# Out:
# Tokenized Document 1: ['updates', 'acute', 'myeloid', 'leukemia', 'review', 'ari', 'pelcovits', 'md', 'rabin', 'niroula', 'md', 'abstract', 'acute', 'myeloid', 'leukemia', 'aml', 'malignancy', 'stem', 'cell', 'precursors', 'myeloid', 'lineage', 'red', 'blood', 'cells', 'platelets', 'white', 'blood', 'cells', 'b', 'cells', 'like', 'malignancies', 'due', 'genetic', 'variations', 'lead', 'neoplastic', 'changes', 'clonal', 'pro', 'liferation', 'aml', 'remains', 'rare', 'malignancy', 'accounting', 'new', 'cancer', 'diagnoses', 'united', 'states', 'per', 'year', 'accounts', 'close', 'one', 'third', 'leukemias', 'diagnosed', 'much', 'early', 'century', 'treatment', 'paradigms', 'unchanged', 'survival', 'curves', 'remaining', 'stagnant', 'many', 'decades', 'recent', 'changes', 'understanding', 'genetic', 'varia', 'tions', 'disease', 'led', 'promising', 'new', 'ther', 'apies', 'hopes', 'improved', 'outcomes', 'future', 'review', 'definitions', 'diagnosis', 'classifica', 'tion', 'aml', 'affects', 'evolving', 'treatment', 'paradigm', 'aml', 'keywords', 'acute', 'myeloid', 'leukemia', 'bone', 'marrow', 'stem', 'cell', 'transplantation', 'aml', 'disease', 'bone', 'marrow', 'disorder', 'hema', 'topoietic', 'stem', 'cells', 'due', 'genetic', 'alterations', 'blood', 'cell', 'precursors', 'resulting', 'overproduction', 'neoplastic', 'clonal', 'myeloid', 'stem', 'cells', 'extramedullary', 'manifestations', 'occur', 'myeloid', 'sarcomas', 'leukemia', 'cutis', 'lying', 'disease', 'due', 'abnormalities', 'hematologic', 'cellular', 'production', 'small', 'subset', 'cases', 'identified', 'caus', 'ative', 'factors', 'prior', 'chemotherapy', 'certain', 'chemical', 'exposures', 'large', 'majority', 'due', 'genetic', 'alter', 'ations', 'chromosomal', 'abnormalities', 'isolated', 'gene', 'mutations', 'without', 'clear', 'causative', 'delineating', 'genetic', 'abnormalities', 'important', 'risk', 'stratifying', 'patients', 'determining', 'appropriate', 'treatment', 'patients', 'aml', 'initially', 'present', 'myriad', 'ways', 'cases', 'disease', 'discovered', 'routine', 'blood', 'work', 'others', 'may', 'present', 'symptomatic', 'complications', 'infection', 'bleeding', 'disseminated', 'intravascular', 'coagulation', 'bone', 'marrow', 'examination', 'paramount', 'establishing', 'diagnosis', 'well', 'obtaining', 'tissue', 'analysis', 'better', 'classify', 'aml', 'subtype', 'prognostic', 'severity', 'world', 'health', 'organization', 'updated', 'guidelines', 'distinguishes', 'six', 'groups', 'aml', 'aml', 'recurrent', 'genetic', 'abnormalities', 'aml', 'myelodyspla', 'changes', 'myeloid', 'neoplasms', 'aml', 'otherwise', 'specified', 'myeloid', 'sarcoma', 'myeloid', 'proliferations', 'related', 'diagnosis', 'made', 'presence', 'blasts', 'periph', 'eral', 'blood', 'bone', 'marrow', 'presence', 'unique', 'genetic', 'abnormalities', 'found', 'bone', 'marrow', 'regardless', 'blast', 'count', 'inv', 'aml', 'classified', 'three', 'prognostic', 'risk', 'groups', 'favorable', 'intermediate', 'adverse', 'table', 'based', 'cytogenetics', 'relatively', 'recent', 'recogni', 'tion', 'molecular', 'diseases', 'subsets', 'distinct', 'favorable', 'inv', 'mutated', 'without', 'biallelic', 'mutated', 'cebpa', 'intermediate', 'mutated', 'high', 'without', 'low', 'normal', 'karyotype', 'cytogenetic', 'abnormalities', 'classified', 'favorable', 'adverse', 'adverse', 'v', 'rearranged', 'inv', 'mecom', 'del', 'complex', 'karyotype', 'monosomal', 'karyotype', 'high', 'mutated', 'mutated', 'mutated', 'risk', 'profile', 'categories', 'determined', 'molecular', 'cytogenetic', 'abnormalities', 'adapted', 'blood', 'en', 'april', 'rhode', 'island', 'medical', 'journal', 'rimj', 'archives', 'april', 'issue', 'webpage', 'rimsupdates', 'contribution', 'cytogenetic', 'risk', 'newly', 'recognized', 'molecular', 'subsets', 'different', 'responses', 'standard', 'ther', 'apeutics', 'prognostic', 'groups', 'predict', 'response', 'stan', 'dard', 'therapy', 'survival', 'one', 'large', 'retrospective ...
# Tokenized Document 2: ['online', 'october', 'tallman', 'bob', 'löwenberg', 'clara', 'bloomfieldtomoki', 'naoe', 'dietger', 'niederwieser', 'gert', 'ossenkoppele', 'miguel', 'sanz', 'jorge', 'sierra', 'martin', 'hervé', 'dombret', 'pierre', 'fenaux', 'david', 'grimwade', 'richard', 'larson', 'francesco', 'hartmut', 'döhner', 'elihu', 'estey', 'sergio', 'amadori', 'frederick', 'appelbaum', 'thomas', 'büchner', 'alan', 'european', 'leukemianetrecommendations', 'international', 'expert', 'panel', 'behalf', 'diagnosis', 'management', 'acute', 'myeloid', 'leukemia', 'adults', 'http', 'information', 'services', 'found', 'articles', 'review', 'articles', 'articles', 'myeloid', 'neoplasia', 'articles', 'free', 'research', 'articles', 'similar', 'topics', 'found', 'following', 'blood', 'collections', 'http', 'reproducing', 'article', 'parts', 'entirety', 'may', 'found', 'online', 'http', 'reprintsinformation', 'ordering', 'reprints', 'may', 'found', 'online', 'http', 'subscriptions', 'ash', 'membership', 'may', 'found', 'online', 'copyright', 'american', 'society', 'hematology', 'rights', 'dc', 'american', 'society', 'hematology', 'l', 'st', 'nw', 'suite', 'blood', 'print', 'issn', 'online', 'issn', 'published', 'weekly', 'personal', 'use', 'brown', 'univ', 'may', 'review', 'article', 'diagnosis', 'management', 'acute', 'myeloid', 'leukemia', 'adults', 'recommendations', 'international', 'expert', 'panel', 'behalf', 'europeanleukemianet', 'hartmut', 'bu', 'herve', 'dietger', 'lo', 'clara', 'internal', 'medicine', 'iii', 'university', 'ulm', 'ulm', 'germany', 'cancer', 'center', 'alliance', 'wa', 'hematology', 'tor', 'vergata', 'university', 'hospital', 'rome', 'italy', 'research', 'division', 'fred', 'hutchinson', 'cancer', 'research', 'center', 'seattle', 'wa', 'university', 'mu', 'mu', 'germany', 'haematology', 'university', 'wales', 'college', 'medicine', 'cardiff', 'united', 'kingdom', 'universitaire', 'ho', 'ˆpital', 'louis', 'assistance', 'ˆpitaux', 'de', 'paris', 'paris', 'france', 'clinique', 'ho', 'ˆpital', 'avicenne', 'bobigny', 'france', 'medical', 'molecular', 'genetics', 'guy', 'king', 'thomas', 'school', 'medicine', 'london', 'united', 'kingdom', 'medicine', 'cancer', 'research', 'center', 'university', 'chicago', 'il', 'biopathology', 'university', 'tor', 'vergata', 'santa', 'lucia', 'foundation', 'centro', 'europeo', 'per', 'la', 'ricerca', 'sul', 'cervello', 'rome', 'italy', 'hematology', 'nagoya', 'university', 'hospital', 'japan', 'hematology', 'oncology', 'hemostasis', 'university', 'leipzig', 'leipzig', 'germany', 'haematology', 'vu', 'university', 'medical', 'center', 'amsterdam', 'netherlands', 'bone', 'marrow', 'transplant', 'unit', 'university', 'hospital', 'la', 'fe', 'valencia', 'spain', 'hematology', 'department', 'hospital', 'de', 'la', 'santa', 'creu', 'sant', 'pau', 'barcelona', 'spain', 'northwestern', 'university', 'feinberg', 'school', 'medicine', 'chicago', 'il', 'hematology', 'erasmus', 'university', 'medical', 'center', 'rotterdam', 'netherlands', 'ohio', 'state', 'university', 'comprehensive', 'cancer', 'center', 'arthur', 'james', 'cancer', 'hospital', 'columbus', 'international', 'working', 'group', 'last', 'reported', 'recommendations', 'fordiagnosis', 'response', 'assessment', 'andtreatment', 'outcomes', 'acute', 'myeloid', 'aml', 'since', 'time', 'progress', 'made', 'molecular', 'pathogenesis', 'thedisease', 'resulted', 'new', 'diagnostic', 'prognosticmarkers', 'furthermore', 'therapies', 'nowbeing', 'developed', 'target', 'molecular', 'defects', 'recent', 'prompted', 'international', 'panel', 'provide', 'updated', 'expert', 'diagnosis', 'managementof', 'aml', 'contain', 'minimal', 'general', 'practice', 'well', 'asstandards', 'clinical', 'trials', 'new', 'reporting', 'system', 'correlationof', 'cytogenetic', 'molecular', 'genetic', 'datawith', 'clinical', 'data', 'proposed', 'blood', 'introduction', 'expert', 'working', 'groups', 'published', 'recommendations', 'diagnosis', 'standardization',  ...

# %%
print("\nDocument Vector 1:", doc_vector_1)
print("Document Vector 2:", doc_vector_2)
# Out:
# Document Vector 1: [-0.06028705  0.09066492 -0.04264551 -0.10434996 -0.01869038 -0.19852982
#  -0.01206556  0.27604583 -0.10428098  0.04017933 -0.05148957 -0.19797249
#  -0.07536412  0.00350058  0.06329219 -0.15101483 -0.01938701 -0.18568449
#   0.00163248 -0.14164081  0.02895941  0.06032033  0.13826632  0.01735337
#  -0.07620387 -0.00333533 -0.08118761 -0.10597454 -0.10576026 -0.04897039
#   0.09297724 -0.00747162  0.10342778 -0.12262674 -0.04300593  0.11723351
#   0.02213829 -0.1322745  -0.05993718 -0.17960238  0.00478922 -0.08480076
#  -0.02860679  0.02897447  0.07425003 -0.00780965 -0.04774154 -0.02881022
#   0.05455728  0.12989186  0.03507204 -0.1513438  -0.03984315 -0.00944226
#  -0.10111815  0.05675543  0.09569385  0.00789309 -0.11208872 -0.04793609
#   0.12254     0.11966821 -0.08379335 -0.00348069  0.01535915  0.04464399
#  -0.02608     0.07802763 -0.17362982  0.05995125 -0.01576983  0.16827916
#   0.12552117  0.02347091  0.20800693  0.04502115 -0.0423705  -0.05305415
#  -0.08278268  0.0786568   0.00202744 -0.02841677 -0.14148407  0.14222616
#  -0.00241522  0.00258531 -0.02016558  0.1773496   0.06031687  0.06055179
#   0.15329462  0.10700246  0.04091473 -0.00032129  0.21681154  0.1240992
#   0.04607668 -0.17979519  0.05613453 -0.01183995]
# Document Vector 2: [-0.05561667  0.08294685 -0.03881441 -0.0945992  -0.01604936 -0.18144318
#  -0.01112662  0.25206706 -0.09613981  0.03696099 -0.0486527  -0.18092732
#  -0.0691051   0.00394788  0.05745178 -0.1387572  -0.01746268 -0.16996832
#   0.00097048 -0.13043308  0.02666993  0.05500337  0.12655242  0.01464926
#  -0.06917273 -0.00265338 -0.0738487  -0.09637012 -0.09703843 -0.0447148
#   0.08533681 -0.00700446  0.09375506 -0.11217333 -0.04023029  0.10652021
#   0.01982995 -0.12094925 -0.05593036 -0.16457732  0.00456736 -0.07851509
#  -0.02617154  0.02656873  0.06836645 -0.00724689 -0.04343307 -0.02695497
#   0.05022498  0.11845821  0.03241343 -0.13854934 -0.03579864 -0.00874539
#  -0.09379964  0.051534    0.08799125  0.00702428 -0.10315368 -0.04315073
#   0.11206555  0.10938115 -0.07681287 -0.00343179  0.01276738  0.04153891
#  -0.02377154  0.07113713 -0.15938541  0.05614097 -0.01529746  0.15335132
#   0.11527485  0.02042353  0.18990128  0.04070354 -0.03871514 -0.04692924
#  -0.07601698  0.07108192  0.00149552 -0.02612345 -0.12996398  0.12909725
#  -0.00146167  0.00175434 -0.01815776  0.16122755  0.05543614  0.05469639
#   0.13936983  0.09754933  0.03697276 -0.00097113  0.197262    0.11307511
#   0.0419963  -0.1642429   0.051275   -0.00954596]

# %%
# Print cosine similarity
print("\nCosine Similarity between the two documents:", similarity[0][0])
# Out:
# Cosine Similarity between the two documents: 0.9999763
