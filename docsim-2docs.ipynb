# %%
#this program compares 2 pdf docs with Word2Vec

# %%
import PyPDF2
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from gensim.models import Word2Vec
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import string

# %%
# Download NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to read text from a PDF file
def read_pdf(file_path):
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
# Preprocess the text
def preprocess(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return tokens

# %%
# Function to generate a document vector using Word2Vec
def get_document_vector(tokens, model):
    vectors = [model.wv[word] for word in tokens if word in model.wv]
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

# %%
# File paths to the two PDF files
file_path_1 = 'Doc1.pdf'
file_path_2 = 'Doc2.pdf'

# %%
# Read and preprocess the text from the PDF files
text1 = preprocess(read_pdf(file_path_1))
text2 = preprocess(read_pdf(file_path_2))

# %%
# Combine the tokenized sentences for training Word2Vec
sentences = [text1, text2]

# %%
# Train a Word2Vec model on the sentences
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, sg=1)

# %%
# Generate document vectors
doc_vector_1 = get_document_vector(text1, model)
doc_vector_2 = get_document_vector(text2, model)

# %%
# Calculate cosine similarity between the two document vectors
similarity = cosine_similarity([doc_vector_1], [doc_vector_2])

# %%
# Print the tokenized sentences and their document vectors
print("Tokenized Document 1:", text1)
print("Tokenized Document 2:", text2)
print("\nDocument Vector 1:", doc_vector_1)
print("Document Vector 2:", doc_vector_2)
# Out:
# Tokenized Document 1: ['genetics', 'molecular', 'research', 'review', 'bioinformatics', 'overview', 'applications', 'de', 'genética', 'e', 'evolução', 'universidade', 'federal', 'de', 'são', 'carlos', 'são', 'carlos', 'sp', 'brasil', 'de', 'química', 'e', 'física', 'molecular', 'instituto', 'de', 'química', 'de', 'são', 'carlos', 'universidade', 'de', 'são', 'paulo', 'são', 'carlos', 'sp', 'brasil', 'corresponding', 'author', 'canduri', 'fcanduri', 'genet', 'mol', 'res', 'received', 'february', 'accepted', 'march', 'published', 'march', 'doi', 'http', 'copyright', 'authors', 'article', 'distributed', 'terms', 'creative', 'commons', 'attribution', 'sharealike', 'cc', 'license', 'abstract', 'technological', 'advancements', 'recent', 'years', 'promoted', 'marked', 'progress', 'understanding', 'genetic', 'basis', 'phenotypes', 'line', 'advances', 'genomics', 'changed', 'paradigm', 'biological', 'questions', 'full', 'scale', 'revealing', 'explosion', 'data', 'opening', 'many', 'possibilities', 'hand', 'vast', 'amount', 'information', 'generated', 'points', 'challenges', 'must', 'overcome', 'storage', 'moore', 'law', 'processing', 'biological', 'information', 'context', 'bioinformatics', 'computational', 'biology', 'sought', 'overcome', 'challenges', 'review', 'presents', 'overview', 'bioinformatics', 'use', 'analysis', 'biological', 'data', 'exploring', 'approaches', 'emerging', 'methodologies', 'tools', 'give', 'biological', 'meaning', 'data', 'generated', 'key', 'words', 'data', 'analysis', 'databases', 'genomics', 'systems', 'diniz', 'canduri', 'genetics', 'molecular', 'research', 'introduction', 'unprecedented', 'r', 'evolution', 'observed', 'science', 'recent', 'technological', 'advances', 'provided', 'large', 'amount', 'omic', 'data', 'crescent', 'generation', 'availability', 'information', 'available', 'public', 'databases', 'still', 'challenge', 'professionals', 'different', 'areas', 'ritchie', 'et', 'however', 'challenge', 'biology', 'main', 'challenge', 'make', 'sense', 'enormous', 'amount', 'structural', 'data', 'sequences', 'generated', 'multiple', 'levels', 'biological', 'systems', 'pevsner', 'still', 'bioinformatics', 'development', 'tools', 'necessary', 'statistical', 'computational', 'capable', 'assisting', 'understanding', 'mechanisms', 'underlying', 'biological', 'questions', 'study', 'pevsner', 'besides', 'consider', 'complexity', 'science', 'highly', 'reductionist', 'view', 'era', 'new', 'biology', 'emerges', 'accompanied', 'sciences', 'bioinformatics', 'computational', 'biology', 'integrated', 'interface', 'molecular', 'biology', 'although', 'considered', 'recently', 'bioinformatics', 'genomics', 'evolved', 'interdependently', 'promoted', 'historical', 'impact', 'available', 'knowledge', 'therefore', 'review', 'aims', 'present', 'brief', 'overview', 'sciences', 'provide', 'principles', 'support', 'bioinformatics', 'addressing', 'following', 'aspects', 'types', 'biological', 'information', 'databases', 'ii', 'sequence', 'analysis', 'molecular', 'modeling', 'iii', 'genomic', 'analysis', 'iv', 'systems', 'biology', 'broad', 'areas', 'seek', 'highlight', 'key', 'points', 'use', 'new', 'techniques', 'well', 'provide', 'tools', 'used', 'data', 'analysis', 'interpretation', 'results', 'generated', 'technologies', 'bio', 'historical', 'conceptual', 'vision', 'bioinformatics', 'bioinformatics', 'origins', 'decade', 'dna', 'sequencing', 'became', 'feasible', 'hagen', 'historical', 'moments', 'highlighted', 'development', 'publication', 'structure', 'dna', 'watson', 'crick', 'besides', 'accumulation', 'data', 'knowledge', 'biochemistry', 'protein', 'structure', 'studies', 'pauling', 'coren', 'ramachandran', 'verli', 'pioneer', 'systematization', 'knowledge', 'protein', 'structure', 'margaret', 'dayhoff', 'considered', 'mother', 'bioinformatics', 'hunt', 'fact', 'due', 'role', 'development', 'computers', 'able', 'determine', 'peptide', 'sequence', 'programs', 'recognize', 'display', 'structures', 'use', 'crystallography',  ...
# Tokenized Document 2: ['bioinformatics', 'new', 'tools', 'applications', 'life', 'science', 'personalized', 'medicine', 'iuliia', 'altino', 'received', 'november', 'november', 'december', 'author', 'exclusive', 'licence', 'gmbh', 'de', 'part', 'springer', 'nature', 'abstract', 'basic', 'understanding', 'functioning', 'gene', 'coding', 'sequences', 'specific', 'proteins', 'feel', 'lack', 'information', 'role', 'dna', 'specific', 'diseases', 'functions', 'thousands', 'proteins', 'produced', 'bioinformatics', 'combines', 'methods', 'used', 'collection', 'storage', 'identification', 'analysis', 'correlation', 'huge', 'complex', 'information', 'work', 'produces', 'ocean', 'information', 'sailed', 'help', 'computerized', 'methods', 'goal', 'provide', 'scientists', 'right', 'means', 'explain', 'normal', 'biological', 'processes', 'dysfunctions', 'processes', 'give', 'rise', 'disease', 'approaches', 'allow', 'discovery', 'new', 'medical', 'cures', 'recently', 'sequencing', 'platforms', 'large', 'scale', 'genomes', 'transcriptomes', 'created', 'new', 'challenges', 'genomics', 'especially', 'bioinformatics', 'intent', 'article', 'compile', 'list', 'tools', 'information', 'resources', 'used', 'scientists', 'treat', 'information', 'massive', 'sequencing', 'recent', 'platforms', 'new', 'generations', 'applications', 'information', 'different', 'areas', 'life', 'sciences', 'including', 'medicine', 'key', 'points', 'data', 'mining', 'approaches', 'genotype', 'phenotype', 'keywords', 'sequencing', 'science', 'medicine', 'introduction', 'knowledge', 'derived', 'genomic', 'computational', 'technologies', 'increases', 'geometric', 'progression', 'standing', 'avalanche', 'data', 'closely', 'linked', 'formidable', 'development', 'bioinformatics', 'area', 'abling', 'overall', 'assessment', 'extraordinary', 'amount', 'data', 'bioinformatics', 'considerably', 'accelerated', 'scientific', 'discoveries', 'growth', 'consequence', 'large', 'supply', 'products', 'services', 'information', 'keep', 'date', 'locate', 'use', 'latest', 'innovations', 'become', 'initially', 'tried', 'create', 'complete', 'profile', 'available', 'bioinformatics', 'resources', 'quickly', 'ident', 'dynamism', 'constant', 'updating', 'field', 'surpassed', 'goal', 'create', 'division', 'four', 'categories', 'sequence', 'analysis', 'software', 'software', 'prediction', 'protein', 'structures', 'resource', 'servers', 'online', 'finally', 'left', 'list', 'places', 'interest', 'internet', 'shorten', 'search', 'time', 'opted', 'selection', 'categories', 'believe', 'analyze', 'comprehensive', 'way', 'molecular', 'biology', 'central', 'dogma', 'bioinformatics', 'scientific', 'area', 'gathering', 'techniques', 'tools', 'subjects', 'molecular', 'biology', 'source', 'formation', 'analyzed', 'informatics', 'computer', 'science', 'provides', 'hardware', 'analysis', 'networks', 'share', 'results', 'mathematics', 'origin', 'rithms', 'used', 'data', 'analysis', 'interrelationship', 'three', 'areas', 'creates', 'basis', 'bioinformatics', 'plications', 'molecular', 'biology', 'seen', 'following', 'diagram', 'li', 'et', 'al', 'f', 'g', 'altino', 'choupina', 'albracho', 'de', 'investigação', 'de', 'montanha', 'cimo', 'instituto', 'politécnico', 'de', 'bragança', 'campus', 'de', 'santa', 'apolónia', 'bragança', 'portugalhttps', 'published', 'online', 'january', 'microbiology', 'biotechnology', 'know', 'many', 'reviews', 'matics', 'tools', 'published', 'review', 'want', 'presentin', 'simple', 'way', 'fundamental', 'useful', 'tools', 'life', 'science', 'researcher', 'work', 'integrating', 'several', 'tools', 'cover', 'omics', 'tools', 'used', 'since', 'design', 'obtaining', 'biological', 'data', 'deposit', 'data', 'mineralization', 'order', 'deduce', 'types', 'interrelationships', 'applications', 'cloning', 'pharmacy', 'medicine', 'review', 'useful', 'biotechnology', 'researchers', 'agronomists', 'zootechnics', 'ecologists', 'pharmacists', 'andmedicine', 'agents', 'martins', 'et', 'al', 'deduce', 'order' ...
#
